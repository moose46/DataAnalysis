# %% [markdown]
# ## Read all_race_data.csv and create a dataframe

# %%
import pandas as pd

df_races = pd.read_csv("all_race_data.csv")
df_races.columns
type(df_races["RACE_TRACK"].unique())
# print(df_races["RACE_TRACK"].unique())
df_races[(df_races["RACE_TRACK"] == 'Bristol') & (df_races["POS"] < 3)].sort_values("RACE_DATE")
# Out:
#     RACE_TRACK            RACE_DATE  POS               DRIVER  CAR  \
# 334    Bristol  2020-05-31 00:00:00    1      Brad Keselowski    2
# 335    Bristol  2020-05-31 00:00:00    2         Clint Bowyer   14
# 448    Bristol  2020-09-19 00:00:00    1        Kevin Harvick    4
# 449    Bristol  2020-09-19 00:00:00    2           Kyle Busch   18
# 222    Bristol  2021-03-28 00:00:00    1          Joey Logano   22
# 223    Bristol  2021-03-28 00:00:00    2  Ricky Stenhouse Jr.   47
# 374    Bristol  2021-09-18 00:00:00    1          Kyle Larson    5
# 375    Bristol  2021-09-18 00:00:00    2        Kevin Harvick    4
# 298    Bristol  2022-04-17 00:00:00    1           Kyle Busch   18
# 299    Bristol  2022-04-17 00:00:00    2        Tyler Reddick    8
# 412    Bristol  2022-09-18 00:00:00    1       Chris Buescher   17
# 413    Bristol  2022-09-18 00:00:00    2        Chase Elliott    9
# 261    Bristol  2023-04-09 00:00:00    1     Christopher Bell   20
# 262    Bristol  2023-04-09 00:00:00    2        Tyler Reddick   45
#
#     MANUFACTURER LAPS  START  LED  PTS  BONUS  PENALTY
# 334         Ford  500      1  115   50      0       10
# 335         Ford  500     23    0   40      0        5
# 448         Ford  500      4  226   57      0       17
# 449       Toyota  500      9  159   54      0       19
# 222         Ford  253     10   61   55      0       15
# 223    Chevrolet  253     13    0   42      0        7
# 374    Chevrolet  500      5  175   59      0       19
# 375         Ford  500      8   71   45      0       10
# 298       Toyota  250     11    1   52      0       12
# 299    Chevrolet  250      3   99   39      0        4
# 412         Ford  500     20  169   44      0        4
# 413    Chevrolet  500     23    0   42      0        7
# 261       Toyota  250      4  100   52      0       12
# 262       Toyota  250      6   69   48      0       13
